# %%
import pickle
import matplotlib.pyplot as plt
import scienceplots
import numpy as np
plt.style.use('science')
import os
import re

from pepsflow.iPEPS_trainer import iPEPSTrainer
from pepsflow.models.observables import Observables

number_pattern = re.compile(r'\d+')
lambda_values = [lam for lam in np.arange(0.1, 4, 0.25)]

# %%
def extract_number(file: str) -> int:
    return int(number_pattern.search(file).group())

def plot_folder(folder: str, obs: str):
    """
    Plots the observable for all the files in the given folder.

    Args:
        folder (str): the folder containing the data
        obs (str): the observable to plot  
    """
    plt.figure(figsize=(6, 4))

    for file in sorted(os.listdir('data/' + folder, ), key=extract_number):
        with open('data/' + folder + '/' + file, 'rb') as f:
            data = pickle.load(f)
    
        chi = int(number_pattern.search(file).group())
        plot_data = np.abs(np.array(data[obs])) if obs == 'Mz' else data[obs]
        plt.plot(data["lambdas"], plot_data, 'v-', markersize=4, linewidth=0.5, label=rf'$\chi = {chi}$')

    plt.xlabel(r'$\lambda$', fontsize=14)
    plt.ylabel(obs, fontsize=14)
    plt.legend()

# %% [markdown]
# # Trying reruns with random initial tensors

# %%
chi_values = [4, 8, 16]
for chi in chi_values:
    trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False)
    trainer.exe(lambda_values, epochs=5, use_prev=False, runs = 5)
    trainer.save_data(fn = f"random/chi{chi}")
# Out:
#   0%|          | 0/16 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 4
#       2 for chi in chi_values:
#       3     trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False)
# ----> 4     trainer.exe(lambda_values, epochs=5, use_prev=False, runs = 5)
#       5     trainer.save_data(fn = f"run4/chi{chi}")
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:80, in iPEPSTrainer.exe(self, lambdas, epochs, use_prev, perturbation, runs)
#      78 while not success:
#      79     try:
# ---> 80         model, training_time = self.train_model(
#      81             lam, epochs, use_prev, perturbation
#      82         )
#      83         success = True
#      84     except torch._C._LinAlgError:
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:131, in iPEPSTrainer.train_model(self, lam, epochs, use_prev, perturbation)
#     128 start_time = time.time()
#     130 for _ in range(epochs):
# --> 131     optimizer.step(train)
#     133 return model, time.time() - start_time
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\optim\lbfgs.py:323, in LBFGS.step(self, closure)
#     320 state.setdefault("n_iter", 0)
#     322 # evaluate initial f(x) and df/dx
# --> 323 orig_loss = closure()
#     324 loss = float(orig_loss)
#     325 current_evals = 1
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:124, in iPEPSTrainer.train_model.<locals>.train()
#     120 """
#     121 Train the parameters of the iPEPS model.
#     122 """
#     123 optimizer.zero_grad()
# --> 124 loss, _, _, _, _, _ = model.forward()
#     125 loss.backward()
#     126 return loss
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS.py:81, in iPEPS.forward(self)
#      79 # Execute the CTM algorithm to compute corner (C) and edge (T) tensors
#      80 alg = CtmAlg(a, chi, d, self.C, self.T)
# ---> 81 alg.exe()
#      83 # Compute the energy (loss) using the Hamiltonian, corner, and edge tensors
#      84 loss, Mx, My, Mz = get_energy(
#      85     Asymm, self.H, alg.C, alg.T, self.Mpx, self.Mpy, self.Mpz
#      86 )
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\models\CTM_alg.py:65, in CtmAlg.exe(self, tol, count, max_steps)
#      62 self.T = symm(norm(self.new_T(U)))
#      64 # Save sum of singular values
# ---> 65 self.sv_sums.append(torch.sum(s).item())
#      67 tol_counter += 1 if abs(self.sv_sums[-1] - self.sv_sums[-2]) < tol else 0
#      69 if tol_counter == count:
#
# KeyboardInterrupt:

# %%
plot_folder('random', 'energies')
plot_folder('random', 'Mz')
plot_folder('random', 'Mg')

# %% [markdown]
# # Reruns with initial tensors from previous lambda runs

# %%
lambda_values = [lam for lam in np.arange(1.5, 4.5, 0.1)]
chi_values = [16]
for chi in chi_values:
    trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False)
    trainer.exe(lambda_values, epochs=5, use_prev=True, lr=0.01, max_iter=20)
    trainer.save_data(fn = f'prev_lambda/chi{chi}')
# Out:
#   0%|          | 0/30 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 5
#       3 for chi in chi_values:
#       4     trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False)
# ----> 5     trainer.exe(lambda_values, epochs=5, use_prev=True, lr=0.01, max_iter=20)
#       6     trainer.save_data(fn = f'prev_lambda/chi{chi}')
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:73, in iPEPSTrainer.exe(self, lambdas, epochs, use_prev, perturbation, runs, lr, max_iter)
#      71 while not success:
#      72     try:
# ---> 73         model, training_time = self.train_model(
#      74             lam, epochs, use_prev, perturbation, lr, max_iter
#      75         )
#      76         success = True
#      77     except torch._C._LinAlgError:
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:132, in iPEPSTrainer.train_model(self, lam, epochs, use_prev, perturbation, lr, max_iter)
#     129 start_time = time.time()
#     131 for _ in range(epochs):
# --> 132     optimizer.step(train)
#     134 return model, time.time() - start_time
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\optim\lbfgs.py:450, in LBFGS.step(self, closure)
#     445 if n_iter != max_iter:
#     446     # re-evaluate function only if not in last iteration
#     447     # the reason we do this: in a stochastic setting,
#     448     # no use to re-evaluate that function here
#     449     with torch.enable_grad():
# --> 450         loss = float(closure())
#     451     flat_grad = self._gather_flat_grad()
#     452     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File c:\Users\derk\Documents\PEPSFlow\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS_trainer.py:125, in iPEPSTrainer.train_model.<locals>.train()
#     121 """
#     122 Train the parameters of the iPEPS model.
#     123 """
#     124 optimizer.zero_grad()
# --> 125 loss, _, _, _, _, _ = model.forward()
#     126 loss.backward()
#     127 return loss
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\iPEPS.py:78, in iPEPS.forward(self)
#      76 # Execute the CTM algorithm to compute corner (C) and edge (T) tensors
#      77 alg = CtmAlg(a, chi, d, self.C, self.T)
# ---> 78 alg.exe()
#      80 if torch.isnan(a).any():
#      81     raise ValueError("NaNs in the tensor network contraction a")
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\models\CTM_alg.py:58, in CtmAlg.exe(self, tol, count, max_steps)
#      55 M = self.new_M()
#      57 # Use `M` to compute the renormalization tensor
# ---> 58 U, s = self.new_U(M)
#      60 # Normalize and symmetrize the new corner and edge tensors
#      61 self.C = symm(norm(self.new_C(U)))
#
# File c:\Users\derk\Documents\PEPSFlow\pepsflow\models\CTM_alg.py:125, in CtmAlg.new_U(self, M)
#     123 M = M.reshape(self.chi * self.d, self.chi * self.d)
#     124 k = self.chi
# --> 125 U, s, Vh = torch.svd(M, some=True)
#     127 # Let chi grow if the desired chi is not yet reached.
#     128 if self.chi >= self.max_chi:
#
# KeyboardInterrupt:

# %%
plot_folder('prev_lambda', 'energies')
plot_folder('prev_lambda', 'Mz')
plot_folder('prev_lambda', 'Mg')

# %% [markdown]
# # Trying reruns with initial tensors from previous runs

# %%
data = pickle.load(open('data/random/chi4.pkl', 'rb'))
chi_values = [8, 16, 32]

for chi in chi_values:
    trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False, data_prev=data)
    trainer.exe(epochs=5, max_iter=30, lr = 0.01)
    trainer.save_data(fn = f"prev_chi_lr/chi{chi}")
    data = trainer.data
    trainer.clear_data()
# Out:
# 100%|██████████| 16/16 [01:21<00:00,  5.10s/it]
# Data saved to data\prev_chi_lr/chi8.pkl
# 100%|██████████| 16/16 [01:54<00:00,  7.13s/it]
# Data saved to data\prev_chi_lr/chi16.pkl
# 100%|██████████| 16/16 [03:49<00:00, 14.35s/it]
# Data saved to data\prev_chi_lr/chi32.pkl

# %%
plot_folder('prev_chi_lr', 'energies')
plot_folder('prev_chi_lr', 'Mz')
plot_folder('prev_chi_lr', 'Mg')

# %% [markdown]
# # Varying the learning rate

# %%
rates = [0.01, 0.1, 1, 2, 10]

# %%
trainer = iPEPSTrainer(chi = 4, d = 2, gpu=False)

for lr in rates:
    trainer.exe(epochs=5, lr=lr, lambdas=lambda_values)
    trainer.save_data(fn = f"lr/lr{lr}")
    trainer.clear_data()
# Out:
# 100%|██████████| 16/16 [01:15<00:00,  4.71s/it]
# Data saved to data\lr/lr0.01.pkl
#  50%|█████     | 8/16 [00:33<00:33,  4.18s/it]
# LinAlgError occurred. Retrying...
# 100%|██████████| 16/16 [01:07<00:00,  4.25s/it]
# Data saved to data\lr/lr0.1.pkl
#  50%|█████     | 8/16 [00:29<00:31,  3.96s/it]
# LinAlgError occurred. Retrying...
#  56%|█████▋    | 9/16 [00:35<00:31,  4.53s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  94%|█████████▍| 15/16 [01:15<00:06,  6.56s/it]
# LinAlgError occurred. Retrying...
# 100%|██████████| 16/16 [01:26<00:00,  5.38s/it]
# Data saved to data\lr/lr1.pkl
#  19%|█▉        | 3/16 [00:12<00:50,  3.87s/it]
# LinAlgError occurred. Retrying...
#  69%|██████▉   | 11/16 [00:45<00:23,  4.67s/it]
# LinAlgError occurred. Retrying...
#  88%|████████▊ | 14/16 [01:01<00:09,  4.95s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  94%|█████████▍| 15/16 [01:10<00:06,  6.15s/it]
# LinAlgError occurred. Retrying...
# 100%|██████████| 16/16 [01:14<00:00,  4.67s/it]
# Data saved to data\lr/lr2.pkl
#  50%|█████     | 8/16 [00:19<00:20,  2.52s/it]
# LinAlgError occurred. Retrying...
#  56%|█████▋    | 9/16 [00:22<00:18,  2.61s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  75%|███████▌  | 12/16 [00:44<00:19,  4.85s/it]
# LinAlgError occurred. Retrying...
#  81%|████████▏ | 13/16 [00:48<00:13,  4.49s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  88%|████████▊ | 14/16 [00:55<00:10,  5.45s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# 100%|██████████| 16/16 [01:02<00:00,  3.93s/it]
# Data saved to data\lr/lr10.pkl

# %%
plot_folder('lr', 'energies')
plt.legend([ f'lr = {lr}' for lr in rates])
plt.show()
plot_folder('lr', 'Mz')
plt.legend([ f'lr = {lr}' for lr in rates])
plt.show()
plot_folder('lr', 'Mg')
plt.legend([ f'lr = {lr}' for lr in rates])
plt.show()

# %% [markdown]
# # Correlation Length

# %%
lambda_values = [lam for lam in np.arange(2.5, 4, 0.05)]
trainer = iPEPSTrainer(chi = 4, d = 2, gpu=False)
trainer.exe(lambda_values, epochs=5, use_prev=False, runs = 5)
trainer.save_data(fn = f"start/chi{chi}")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# LinAlgError occurred. Retrying...
#   3%|▎         | 1/30 [00:17<08:34, 17.74s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  10%|█         | 3/30 [00:56<08:28, 18.82s/it]
# LinAlgError occurred. Retrying...
#  13%|█▎        | 4/30 [01:13<07:51, 18.13s/it]
# LinAlgError occurred. Retrying...
#  17%|█▋        | 5/30 [01:29<07:16, 17.44s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  20%|██        | 6/30 [02:20<11:29, 28.73s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  27%|██▋       | 8/30 [02:51<07:51, 21.44s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  33%|███▎      | 10/30 [03:27<06:25, 19.28s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  37%|███▋      | 11/30 [03:50<06:29, 20.48s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  43%|████▎     | 13/30 [04:24<05:15, 18.57s/it]
# LinAlgError occurred. Retrying...
#  50%|█████     | 15/30 [05:00<04:32, 18.15s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  53%|█████▎    | 16/30 [05:18<04:17, 18.39s/it]
# LinAlgError occurred. Retrying...
#  57%|█████▋    | 17/30 [05:42<04:17, 19.81s/it]
# LinAlgError occurred. Retrying...
#  60%|██████    | 18/30 [05:59<03:49, 19.15s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  63%|██████▎   | 19/30 [06:18<03:29, 19.03s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  70%|███████   | 21/30 [06:50<02:37, 17.52s/it]
# LinAlgError occurred. Retrying...
#  77%|███████▋  | 23/30 [07:33<02:20, 20.02s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
#  80%|████████  | 24/30 [07:50<01:53, 18.98s/it]
# LinAlgError occurred. Retrying...
#  90%|█████████ | 27/30 [08:31<00:47, 15.78s/it]
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# LinAlgError occurred. Retrying...
# 100%|██████████| 30/30 [09:22<00:00, 18.74s/it]
# Data saved to data\start/chi16.pkl

# %%
data = pickle.load(open('data/start/chi16.pkl', 'rb'))
plt.figure(figsize=(6, 4))
plt.plot(data["lambdas"], data["energies"], 'v-', markersize=4, linewidth=0.5)
plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$E$', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
Mx, My, Mz = Observables.M(data["states"], data["C"], data["T"])
plt.plot(data["lambdas"], abs(np.array(Mz)), 'v-', markersize=4, linewidth=0.5)
plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$M$', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(data["lambdas"], Observables.xi(data["T"]), 'v-', markersize=4, linewidth=0.5)
plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\xi$', fontsize=14)
plt.show()

# %%
start_data = pickle.load(open('data/start/chi24.pkl', 'rb'))

for chi in [28]:
    trainer = iPEPSTrainer(chi = chi, d = 2, gpu=False, data_prev=start_data)
    trainer.exe(epochs=5, max_iter=5, lr = 0.01, perturbation=1e-3)
    trainer.save_data(fn = f"start/chi{chi}")
    data = trainer.data
    trainer.clear_data()
# Out:
#  77%|███████▋  | 23/30 [01:07<00:16,  2.32s/it]

# %%
plt.figure(figsize=(6, 4))
for chi in [16, 24, 28]:
    data = pickle.load(open(f'data/start/chi{chi}.pkl', 'rb'))
    plt.plot(data["lambdas"], Observables.xi(data["T"]), 'v-', markersize=4, linewidth=0.5, label=rf'$\chi = {chi}$')

plt.legend()
plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\xi$', fontsize=14)
plt.show()

plt.figure(figsize=(6, 4))
for chi in [16, 24, 28]:
    data = pickle.load(open(f'data/start/chi{chi}.pkl', 'rb'))
    plt.plot(data["lambdas"], abs(np.array(Observables.M(data["states"], data["C"], data["T"])[2])), 'v-', markersize=4, linewidth=0.5, label=rf'$\chi = {chi}$')

plt.legend()
plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$Mz$', fontsize=14)
plt.show()
